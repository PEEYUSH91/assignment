# %%
Q1.import numpy as np

# %%
arr = np.array([1, 2, 3],
               [4, 5, 6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 arr = np.array([1, 2, 3],
#       2                [4, 5, 6])
#
# TypeError: Field elements must be 2- or 3-tuples, got '4'

# %%
arr.shape
# Out:
# (2, 3)

# %%
Q2. import numpy as np

# %%
arr = np.array([1, 2, 3],
                [4, 5, 6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 arr = np.array([1, 2, 3],
#       2                 [4, 5, 6])
#
# TypeError: Field elements must be 2- or 3-tuples, got '4'

# %%
arr.dtype
# Out:
# dtype('int32')

# %%
Q3. import pandas as pd

# %%
df = pd.DataFrame({
    'Price': [18000, 18150, 17980]}, index=['NIFTY', 'SENSEX', 'BANKNIFTY'])

# %%
df.index.nunique()
# Out:
# 3

# %%
Q4. import pandas as pd

# %%
df = pd.DataFrame(
    {'Price': [100, 105, 102]},
    index=pd.to_datetime(['2024-01-01', '2024-01-03', '2024-01-05'])
)

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2024-01-01 00:00:00'), Timestamp('2024-01-05 00:00:00'))

# %%
Q5. import numpy as np

# %%
arr = np.array([10, 20, np.nan, 40])

# %%
np.isnan(arr)
# Out:
# array([False, False,  True, False])

# %%
Q6. import numpy as np

# %%
arr = np.array([10, 5, -3, 8])

# %%
arr < 0
# Out:
# array([False, False,  True, False])

# %%
(arr < 0).any()
# Out:
# True

# %%
Q7. import pandas as pd

# %%
df = pd.DataFrame({
    'GDP_Growth_%': [6.1, 5.8, 7.2, 6.5, 4.9]
})

# %%
df['GDP_Growth_%'].describe()
# Out:
# count    5.000000
# mean     6.100000
# std      0.851469
# min      4.900000
# 25%      5.800000
# 50%      6.100000
# 75%      6.500000
# max      7.200000
# Name: GDP_Growth_%, dtype: float64

# %%
Q8. import numpy as np

# %%
volume = np.array([12000, 0, 50, 30000, 2])

# %%
volume == 0
# Out:
# array([False,  True, False, False, False])

# %%
volume < 100
# Out:
# array([False,  True,  True, False,  True])

# %%
np.sum(volume < 100)
# Out:
# 3

# %%
Q9. import numpy as np

# %%
arr = np.array([
    [1, 100],
    [2, 200],
    [1, 100]
])

# %%
np.unique(arr, axis=0)
# Out:
# array([[  1, 100],
#        [  2, 200]])

# %%
len(arr) - len(np.unique(arr, axis=0))
# Out:
# 1

# %%
Q10. import numpy as np

# %%
oil = np.array([60, 62, 61, 120, 59, 58])

# %%
z = (oil - oil.mean()) / oil.std()
oil[np.abs(z) > 3]
# Out:
# array([], dtype=int32)

# %%
Q11. import pandas as pd

# %%
df = pd.DataFrame({
    'Inflation_Rate_%': [6.7, 5.9, 6.2, 4.8, 7.1]
})

# %%
df['Inflation_Rate_%'].describe()
# Out:
# count    5.000000
# mean     6.140000
# std      0.879204
# min      4.800000
# 25%      5.900000
# 50%      6.200000
# 75%      6.700000
# max      7.100000
# Name: Inflation_Rate_%, dtype: float64

# %%
Q12. import pandas as pd

# %%
df = pd.DataFrame({
    'Unemployment_Rate_%': [7.2, 6.9, 7.5, 6.8, 7.1]
})

# %%
df['Unemployment_Rate_%'].mean()
# Out:
# 7.1

# %%
Q13. import numpy as np

# %%
volumes = np.array([120000, 250000, 180000])
indices = np.array(['NIFTY', 'SENSEX', 'BANKNIFTY'])

# %%
indices[np.argmax(volumes)]
# Out:
# 'SENSEX'

# %%
Q14. import numpy as np

# %%
indices = np.array(['NIFTY', 'SENSEX', 'NIFTY', 'BANKNIFTY', 'NIFTY'])

# %%
unique, counts = np.unique(indices, return_counts=True)
dict(zip(unique, counts))
# Out:
# {'BANKNIFTY': 1, 'NIFTY': 3, 'SENSEX': 1}

# %%
Q15. import numpy as np

# %%
inflation = np.array([6.5, 6.2, 5.8, 6.9, 7.1])
interest  = np.array([5.0, 5.2, 5.5, 5.8, 6.0])

# %%
np.corrcoef(inflation, interest)
# Out:
# array([[1.        , 0.58968404],
#        [0.58968404, 1.        ]])

# %%
Q16. import numpy as np

# %%
cci = np.array([95, 98, 102, 100, 97])

# %%
np.mean(cci)
# Out:
# 98.4

# %%
Q17. import numpy as np

# %%
data = np.array([
    [100, 6.5, 95],  # Price, Inflation, CCI
    [105, 6.2, 98],
    [102, 5.8, 102],
    [108, 6.9, 100],
    [101, 7.1, 97]])

# %%
stds = np.std(data, axis=0)

# %%
np.argmax(stds)
# Out:
# 0

# %%
Q18. import numpy as np

# %%
gold_prices = np.array([1800, 1820, 1815, 1850, 1790])

# %%
np.max(gold_prices)
# Out:
# 1850

# %%
Q19. import pandas as pd

# %%
df = pd.DataFrame({
    'Date': pd.to_datetime(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04']),
    'Crude_Oil_Price': [60, 62, 61, 65]
})

# %%
df.loc[df['Crude_Oil_Price'].idxmax(), 'Date']
# Out:
# Timestamp('2024-01-04 00:00:00')

# %%
Q20. import pandas as pd

# %%
df = pd.DataFrame({
    'Corporate_Profit': [500, 520, 510, 550, 530]
})

# %%
df['Corporate_Profit'].mean()
# Out:
# 522.0
